# %%
import os
import re
import time
import logging
import MySQLdb
import requests
import warnings
from google.cloud import translate
logging.basicConfig(filename='log_file.log', level=logging.DEBUG,
						format='Time: %(asctime)s, Logged At Line: %(lineno)d, %(message)s')


logging.info('Info: {}'.format("translater Script Running."))

translate_client = translate.Client.from_service_account_json('updraft-data-API-key.txt')

warnings.filterwarnings('ignore', category=MySQLdb.Warning)

#logging module used for log file creation
logging.basicConfig(filename='log_file.log', level=logging.DEBUG,
                format='Time: %(asctime)s, Logged At Line: %(lineno)d, %(message)s')

try:
    conn=MySQLdb.connect(host='localhost',user='root',passwd='')
    conn.set_character_set('utf8')
    cursor = conn.cursor()
    cursor.execute('SET NAMES utf8;')
    cursor.execute('SET CHARACTER SET utf8;')
    cursor.execute('SET character_set_connection=utf8;')
    logging.info('info:Database loaded successfully.')

except Exception as error:
    logging.critical('Error: {}'.format(error))
    logging.info('Info: {}'.format("translator Script Closed."))
    exit("error, see logs")


#load text files that contains ids of already translated articles


#fetch all english articles
cursor.execute('use main_database')
cursor.execute('select * from english_database')
entries = cursor.fetchall()		

# ### Language Codes: 
# Telugu : 'te' 
# Tamil : 'ta' 
# Kannada : 'kn' 
# Bengali : 'bn' 
# Hindi : 'hi' 

languages = {'hindi':'hi','tamil':'ta','kannada':'kn','bengali':'bn','telugu':'te'}

# %%
try:
        ids_file = open(r'C:\Users\shashank\Desktop\sql_implementation\translated_articles_ids.txt','r')
        ids = ids_file.readlines()
        ids = [id.rstrip() for id in ids]
        ids_file.close()
        logging.info('Info: {}'.format("translated articles ids extracted."))

except Exception as error:
        logging.error('Error: {}'.format(error))
        logging.info('Info: {}'.format("translator Script Closed."))
        exit("error,see logs")
        
print(ids)
def new_id(id):
    if id in ids:
        return False
    else:
        return True
# Out:
# []

# %%
k=0
for entry in entries:
    ide=entry[0]
    title=entry[1]
    link=entry[2]
    source=entry[3]
    summary=entry[4]
    content=entry[5]
    published_date=entry[6]
    if new_id(ide):
            flag=0
            for language,code in languages.items():
                
                    print("TRANSLATION FOR ARTICLE NO.= ",k, "STARTED IN ",language.upper(),"LANGUAGE")
                    
                    while(1):

                        try:
                            translation = translate_client.translate(title,source_language='en',target_language=code)
                            translated_title = translation['translatedText']
                            print("title for article no. ",k," translated." )
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                        
                    
                    while(1):

                        try:
                            translation = translate_client.translate(summary,source_language='en',target_language=code)
                            translated_summary = translation['translatedText']
                            print("summary for article no. ",k," translated." )
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                        


                    
                    #breaking of big content text into parts
                    j=0
                    stop_count=0
                    original_content_parts=[]
                    for i in range(0,len(content)):
                        #print(text[j:i])
                        if i == len(content)-1:
                            original_content_parts.append(content[j:i+1])
                            break
                        if content[i]==".":
                            stop_count=stop_count+1
                            if stop_count%50==0:
                                original_content_parts.append(content[j:i])
                                j=i+1
                                
                                
                    print("Total original parts made for content of article no. ",k," is = ",len(original_content_parts))
                    translated_content_parts=[]
                    
                    #translating each part of content
                    for part in original_content_parts:
                        while (1):
                            try:
                                translation = translate_client.translate(part,source_language='en',target_language=code)
                                translated_content_parts.append(translation['translatedText'])
                                break
                            except:
                                print("sleeping for 10 seconds due to user limit exceed")
                                time.sleep(10)
                    print("Total translated parts made for content of article no. ",k," is = ",len(translated_content_parts))

                    if 'hindi' in language:
                        translated_content = "|".join(translated_content_parts)
                    elif 'bengali' in language:
                        translated_content = "|".join(translated_content_parts)
                    else:
                        translated_content = ".".join(translated_content_parts)
                    
                    
                    
                   # tester, ignore.
                    while(1):
                        try:
                            translation = translate_client.translate(content,source_language='en',target_language=code)
                            checker = translation['translatedText']
                            break
                        except:
                            print("sleeping for 10 seconds due to user limit exceed")
                            time.sleep(10)
                    print("SIZE OF TRANSLATED CONTENT IF NOT BREAKED = ",len(checker))
                    print("SIZE OF TRANSLATED CONTENT IF BREAKED = ",len(translated_content))
                    
                    
                    string = language + '_database'
                    try:
                        cursor.execute('use main_database')
                        query_string = 'insert ' + string + ' values (%s,%s,%s,%s,%s,%s,%s)'
                        cursor.execute(query_string,(ide,translated_title,link,source,translated_summary,translated_content,published_date))
                        print("article ",i," translated for ",language," language\n")
                    except:
                        continue
                   

            
            
            
            conn.commit()	
            print("ARTICLE NO.",k,"HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE")
            k=k+1
            
            with open(r'C:\Users\shashank\Desktop\sql_implementation\translated_articles_ids.txt','a') as f:
                f.write('{}\n'.format(ide))
            logging.info('Info: Article successfully translated with id : {}'.format(ide))
    else:
        print("article skipped for translation already translated")
# Out:
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  HINDI LANGUAGE
# title for article no.  0  translated.
# summary for article no.  0  translated.
# Total original parts made for content of article no.  0  is =  1
# Total translated parts made for content of article no.  0  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1349
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1349
# article  1405  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  TAMIL LANGUAGE
# title for article no.  0  translated.
# summary for article no.  0  translated.
# Total original parts made for content of article no.  0  is =  1
# Total translated parts made for content of article no.  0  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1389
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1389
# article  1405  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  KANNADA LANGUAGE
# title for article no.  0  translated.
# summary for article no.  0  translated.
# Total original parts made for content of article no.  0  is =  1
# Total translated parts made for content of article no.  0  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1315
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1315
# article  1405  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  BENGALI LANGUAGE
# title for article no.  0  translated.
# summary for article no.  0  translated.
# Total original parts made for content of article no.  0  is =  1
# Total translated parts made for content of article no.  0  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1207
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1207
# article  1405  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  0 STARTED IN  TELUGU LANGUAGE
# title for article no.  0  translated.
# summary for article no.  0  translated.
# Total original parts made for content of article no.  0  is =  1
# Total translated parts made for content of article no.  0  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1302
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1302
# article  1405  translated for  telugu  language
#
# ARTICLE NO. 0 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  1 STARTED IN  HINDI LANGUAGE
# title for article no.  1  translated.
# summary for article no.  1  translated.
# Total original parts made for content of article no.  1  is =  1
# Total translated parts made for content of article no.  1  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6799
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6799
# article  6823  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  1 STARTED IN  TAMIL LANGUAGE
# title for article no.  1  translated.
# summary for article no.  1  translated.
# Total original parts made for content of article no.  1  is =  1
# Total translated parts made for content of article no.  1  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  7172
# SIZE OF TRANSLATED CONTENT IF BREAKED =  7172
# article  6823  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  1 STARTED IN  KANNADA LANGUAGE
# title for article no.  1  translated.
# summary for article no.  1  translated.
# Total original parts made for content of article no.  1  is =  1
# Total translated parts made for content of article no.  1  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6413
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6413
# article  6823  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  1 STARTED IN  BENGALI LANGUAGE
# title for article no.  1  translated.
# summary for article no.  1  translated.
# Total original parts made for content of article no.  1  is =  1
# Total translated parts made for content of article no.  1  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6384
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6384
# article  6823  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  1 STARTED IN  TELUGU LANGUAGE
# title for article no.  1  translated.
# summary for article no.  1  translated.
# Total original parts made for content of article no.  1  is =  1
# Total translated parts made for content of article no.  1  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6549
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6549
# article  6823  translated for  telugu  language
#
# ARTICLE NO. 1 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  2 STARTED IN  HINDI LANGUAGE
# title for article no.  2  translated.
# summary for article no.  2  translated.
# Total original parts made for content of article no.  2  is =  1
# Total translated parts made for content of article no.  2  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1131
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1131
# article  1298  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  2 STARTED IN  TAMIL LANGUAGE
# title for article no.  2  translated.
# summary for article no.  2  translated.
# Total original parts made for content of article no.  2  is =  1
# Total translated parts made for content of article no.  2  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1226
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1226
# article  1298  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  2 STARTED IN  KANNADA LANGUAGE
# title for article no.  2  translated.
# summary for article no.  2  translated.
# Total original parts made for content of article no.  2  is =  1
# Total translated parts made for content of article no.  2  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1148
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1148
# article  1298  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  2 STARTED IN  BENGALI LANGUAGE
# title for article no.  2  translated.
# summary for article no.  2  translated.
# Total original parts made for content of article no.  2  is =  1
# Total translated parts made for content of article no.  2  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1080
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1080
# article  1298  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  2 STARTED IN  TELUGU LANGUAGE
# title for article no.  2  translated.
# summary for article no.  2  translated.
# Total original parts made for content of article no.  2  is =  1
# Total translated parts made for content of article no.  2  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1101
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1101
# article  1298  translated for  telugu  language
#
# ARTICLE NO. 2 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  3 STARTED IN  HINDI LANGUAGE
# title for article no.  3  translated.
# summary for article no.  3  translated.
# Total original parts made for content of article no.  3  is =  1
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# Total translated parts made for content of article no.  3  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1794
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1794
# article  1977  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  3 STARTED IN  TAMIL LANGUAGE
# title for article no.  3  translated.
# summary for article no.  3  translated.
# Total original parts made for content of article no.  3  is =  1
# Total translated parts made for content of article no.  3  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1912
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1912
# article  1977  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  3 STARTED IN  KANNADA LANGUAGE
# title for article no.  3  translated.
# summary for article no.  3  translated.
# Total original parts made for content of article no.  3  is =  1
# Total translated parts made for content of article no.  3  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1812
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1812
# article  1977  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  3 STARTED IN  BENGALI LANGUAGE
# title for article no.  3  translated.
# summary for article no.  3  translated.
# Total original parts made for content of article no.  3  is =  1
# Total translated parts made for content of article no.  3  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1672
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1672
# article  1977  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  3 STARTED IN  TELUGU LANGUAGE
# title for article no.  3  translated.
# summary for article no.  3  translated.
# Total original parts made for content of article no.  3  is =  1
# Total translated parts made for content of article no.  3  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1697
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1697
# article  1977  translated for  telugu  language
#
# ARTICLE NO. 3 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  4 STARTED IN  HINDI LANGUAGE
# title for article no.  4  translated.
# summary for article no.  4  translated.
# Total original parts made for content of article no.  4  is =  1
# Total translated parts made for content of article no.  4  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1872
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1872
# article  2044  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  4 STARTED IN  TAMIL LANGUAGE
# title for article no.  4  translated.
# summary for article no.  4  translated.
# Total original parts made for content of article no.  4  is =  1
# Total translated parts made for content of article no.  4  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1963
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1963
# article  2044  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  4 STARTED IN  KANNADA LANGUAGE
# title for article no.  4  translated.
# summary for article no.  4  translated.
# Total original parts made for content of article no.  4  is =  1
# Total translated parts made for content of article no.  4  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1938
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1938
# article  2044  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  4 STARTED IN  BENGALI LANGUAGE
# title for article no.  4  translated.
# summary for article no.  4  translated.
# Total original parts made for content of article no.  4  is =  1
# Total translated parts made for content of article no.  4  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1751
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1751
# article  2044  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  4 STARTED IN  TELUGU LANGUAGE
# title for article no.  4  translated.
# summary for article no.  4  translated.
# Total original parts made for content of article no.  4  is =  1
# Total translated parts made for content of article no.  4  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1885
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1885
# article  2044  translated for  telugu  language
#
# ARTICLE NO. 4 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  5 STARTED IN  HINDI LANGUAGE
# title for article no.  5  translated.
# summary for article no.  5  translated.
# Total original parts made for content of article no.  5  is =  1
# Total translated parts made for content of article no.  5  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  3216
# SIZE OF TRANSLATED CONTENT IF BREAKED =  3216
# article  3271  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  5 STARTED IN  TAMIL LANGUAGE
# title for article no.  5  translated.
# summary for article no.  5  translated.
# Total original parts made for content of article no.  5  is =  1
# Total translated parts made for content of article no.  5  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  3301
# SIZE OF TRANSLATED CONTENT IF BREAKED =  3301
# article  3271  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  5 STARTED IN  KANNADA LANGUAGE
# title for article no.  5  translated.
# summary for article no.  5  translated.
# Total original parts made for content of article no.  5  is =  1
# Total translated parts made for content of article no.  5  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  3073
# SIZE OF TRANSLATED CONTENT IF BREAKED =  3073
# article  3271  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  5 STARTED IN  BENGALI LANGUAGE
# title for article no.  5  translated.
# summary for article no.  5  translated.
# Total original parts made for content of article no.  5  is =  1
# Total translated parts made for content of article no.  5  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2957
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2957
# article  3271  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  5 STARTED IN  TELUGU LANGUAGE
# title for article no.  5  translated.
# summary for article no.  5  translated.
# Total original parts made for content of article no.  5  is =  1
# Total translated parts made for content of article no.  5  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  3045
# SIZE OF TRANSLATED CONTENT IF BREAKED =  3045
# article  3271  translated for  telugu  language
#
# ARTICLE NO. 5 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  6 STARTED IN  HINDI LANGUAGE
# title for article no.  6  translated.
# summary for article no.  6  translated.
# Total original parts made for content of article no.  6  is =  2
# Total translated parts made for content of article no.  6  is =  2
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6457
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6475
# article  6528  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  6 STARTED IN  TAMIL LANGUAGE
# title for article no.  6  translated.
# summary for article no.  6  translated.
# Total original parts made for content of article no.  6  is =  2
# Total translated parts made for content of article no.  6  is =  2
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6460
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6589
# article  6528  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  6 STARTED IN  KANNADA LANGUAGE
# title for article no.  6  translated.
# summary for article no.  6  translated.
# Total original parts made for content of article no.  6  is =  2
# Total translated parts made for content of article no.  6  is =  2
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6512
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6455
# article  6528  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  6 STARTED IN  BENGALI LANGUAGE
# title for article no.  6  translated.
# summary for article no.  6  translated.
# Total original parts made for content of article no.  6  is =  2
# Total translated parts made for content of article no.  6  is =  2
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  5937
# SIZE OF TRANSLATED CONTENT IF BREAKED =  5917
# article  6528  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  6 STARTED IN  TELUGU LANGUAGE
# title for article no.  6  translated.
# summary for article no.  6  translated.
# Total original parts made for content of article no.  6  is =  2
# Total translated parts made for content of article no.  6  is =  2
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  6092
# SIZE OF TRANSLATED CONTENT IF BREAKED =  6147
# article  6528  translated for  telugu  language
#
# ARTICLE NO. 6 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  7 STARTED IN  HINDI LANGUAGE
# title for article no.  7  translated.
# summary for article no.  7  translated.
# Total original parts made for content of article no.  7  is =  1
# Total translated parts made for content of article no.  7  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2920
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2920
# article  2905  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  7 STARTED IN  TAMIL LANGUAGE
# title for article no.  7  translated.
# summary for article no.  7  translated.
# Total original parts made for content of article no.  7  is =  1
# Total translated parts made for content of article no.  7  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  3028
# SIZE OF TRANSLATED CONTENT IF BREAKED =  3028
# article  2905  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  7 STARTED IN  KANNADA LANGUAGE
# title for article no.  7  translated.
# summary for article no.  7  translated.
# Total original parts made for content of article no.  7  is =  1
# Total translated parts made for content of article no.  7  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2811
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2811
# article  2905  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  7 STARTED IN  BENGALI LANGUAGE
# title for article no.  7  translated.
# summary for article no.  7  translated.
# Total original parts made for content of article no.  7  is =  1
# Total translated parts made for content of article no.  7  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2550
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2550
# article  2905  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  7 STARTED IN  TELUGU LANGUAGE
# title for article no.  7  translated.
# summary for article no.  7  translated.
# Total original parts made for content of article no.  7  is =  1
# Total translated parts made for content of article no.  7  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2662
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2662
# article  2905  translated for  telugu  language
#
# ARTICLE NO. 7 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  8 STARTED IN  HINDI LANGUAGE
# title for article no.  8  translated.
# summary for article no.  8  translated.
# Total original parts made for content of article no.  8  is =  1
# Total translated parts made for content of article no.  8  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1895
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1895
# article  1945  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  8 STARTED IN  TAMIL LANGUAGE
# title for article no.  8  translated.
# summary for article no.  8  translated.
# Total original parts made for content of article no.  8  is =  1
# Total translated parts made for content of article no.  8  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1950
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1950
# article  1945  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  8 STARTED IN  KANNADA LANGUAGE
# title for article no.  8  translated.
# summary for article no.  8  translated.
# Total original parts made for content of article no.  8  is =  1
# Total translated parts made for content of article no.  8  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  2014
# SIZE OF TRANSLATED CONTENT IF BREAKED =  2014
# article  1945  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  8 STARTED IN  BENGALI LANGUAGE
# title for article no.  8  translated.
# summary for article no.  8  translated.
# Total original parts made for content of article no.  8  is =  1
# Total translated parts made for content of article no.  8  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1789
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1789
# article  1945  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  8 STARTED IN  TELUGU LANGUAGE
# title for article no.  8  translated.
# summary for article no.  8  translated.
# Total original parts made for content of article no.  8  is =  1
# Total translated parts made for content of article no.  8  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1787
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1787
# article  1945  translated for  telugu  language
#
# ARTICLE NO. 8 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
# TRANSLATION FOR ARTICLE NO.=  9 STARTED IN  HINDI LANGUAGE
# title for article no.  9  translated.
# summary for article no.  9  translated.
# Total original parts made for content of article no.  9  is =  1
# Total translated parts made for content of article no.  9  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  948
# SIZE OF TRANSLATED CONTENT IF BREAKED =  948
# article  981  translated for  hindi  language
#
# TRANSLATION FOR ARTICLE NO.=  9 STARTED IN  TAMIL LANGUAGE
# title for article no.  9  translated.
# summary for article no.  9  translated.
# Total original parts made for content of article no.  9  is =  1
# Total translated parts made for content of article no.  9  is =  1
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# sleeping for 10 seconds due to user limit exceed
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1089
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1089
# article  981  translated for  tamil  language
#
# TRANSLATION FOR ARTICLE NO.=  9 STARTED IN  KANNADA LANGUAGE
# title for article no.  9  translated.
# summary for article no.  9  translated.
# Total original parts made for content of article no.  9  is =  1
# Total translated parts made for content of article no.  9  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1071
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1071
# article  981  translated for  kannada  language
#
# TRANSLATION FOR ARTICLE NO.=  9 STARTED IN  BENGALI LANGUAGE
# title for article no.  9  translated.
# summary for article no.  9  translated.
# Total original parts made for content of article no.  9  is =  1
# Total translated parts made for content of article no.  9  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  971
# SIZE OF TRANSLATED CONTENT IF BREAKED =  971
# article  981  translated for  bengali  language
#
# TRANSLATION FOR ARTICLE NO.=  9 STARTED IN  TELUGU LANGUAGE
# title for article no.  9  translated.
# summary for article no.  9  translated.
# Total original parts made for content of article no.  9  is =  1
# Total translated parts made for content of article no.  9  is =  1
# SIZE OF TRANSLATED CONTENT IF NOT BREAKED =  1011
# SIZE OF TRANSLATED CONTENT IF BREAKED =  1011
# article  981  translated for  telugu  language
#
# ARTICLE NO. 9 HAS BEEN SUCCCESSFULLY TRANSLATED AND PUSHED INTO DATABASE
